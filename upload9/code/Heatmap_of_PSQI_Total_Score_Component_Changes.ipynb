# %% [markdown]
# # 使用前后PSQI总分及各成份变化热力图

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.font_manager as fm
import numpy as np
import pandas as pd
import json

# %%
# 定义中文字体防止乱码
font_path = '../data/SimHei.ttf'
font_prop = fm.FontProperties(fname=font_path)

# %%
# 姓名、psqi总分及各成份数据
categories = ['陈东升', '从建明', '费艳冬', '甘颖婷', '刘汪昊', '藕有娣', '汤荀', '王瑜', '杨雅兰', '韩思洁','俞志江','郑慧', '徐悦', '沈发琴', '沈士国']

scores_right = {
    'A': np.array([2, 2, 2, 2, 2, 3, 3, 2, 2, 3, 2, 2, 2, 2, 2]),
    'B': np.array([2, 3, 3, 2, 2, 3, 3, 2, 3, 3, 3, 3, 2, 3, 1]),
    'C': np.array([1, 2, 2, 2, 2, 3, 2, 2, 0, 1, 3, 2, 0, 3, 0]),
    'D': np.array([1, 3, 1, 1, 3, 3, 1, 2, 2, 2, 3, 0, 0, 3, 0]),
    'E': np.array([2, 1, 2, 1, 2, 2, 1, 2, 1, 2, 2, 1, 1, 1, 0]),
    'F': np.array([0, 3, 1, 0, 2, 3, 3, 0, 3, 0, 0, 3, 3, 2, 3]),
    'G': np.array([2, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 2, 1]),
}

scores_left = {
    'A': np.array([1, 1, 2, 0, 2, 3, 2, 1, 1, 2, 1, 2, 2, 2, 3]),
    'B': np.array([0, 0, 2, 1, 2, 3, 2, 1, 2, 1, 2, 3, 3, 3, 3]),
    'C': np.array([1, 0, 2, 2, 1, 3, 1, 0, 0, 1, 2, 2, 0, 3, 2]),
    'D': np.array([0, 0, 1, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 3, 0]),
    'E': np.array([1, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 1, 2]),
    'F': np.array([0, 3, 0, 0, 0, 3, 3, 0, 1, 0, 1, 3, 3, 3, 3]),
    'G': np.array([1, 3, 2, 3, 3, 3, 3, 1, 2, 2, 0, 3, 2, 3, 2]),
}

# %%
#  遍历每个类别，并将使用前后的分数整理到字典中
data = {}
for i, category in enumerate(categories):
    data[f"{category}使用前"] = list(scores_right[letter][i] for letter in 'ABCDEFG')
    data[f"{category}使用后"] = list(scores_left[letter][i] for letter in 'ABCDEFG')

# 将字典转换为DataFrame
df = pd.DataFrame(data)

# 调整JSON格式以匹配示例
df_json = df.to_json(orient='columns', force_ascii=False, indent=4)
# 将JSON字符串转换为字典
df_json = json.loads(df_json)  # Convert to dict
# 格式化为所需的形式
formatted_json = {k: v for k, v in df_json.items()}  # Format as desired

data = {}
# 遍历格式化后的JSON数据，整理为新的字典结构
for key, value in formatted_json.items():
    data[key] = list(value.values())

# 将数据反转，使其顺序与原始顺序相反
reversed_data = {k: data[k] for k in reversed(data)}

data = reversed_data

result = {}
# 计算每个类别的总分，并将总分和各项分数整理到结果字典中
for key, values in data.items():
    total_score = sum(values)
    # 将总分和分数放入结果中
    result[key] = [total_score] + values

# 转换成DataFrame
df = pd.DataFrame(result)

# %%
# 计算相对变化
relative_change = (df.filter(like='使用后').values - df.filter(like='使用前').values)

# 用新的计算值更新 DataFrame
relative_change_df = pd.DataFrame(
    relative_change,
    index=df.index,
    columns=[col.replace('使用前', '') for col in df.columns if '使用前' in col]
)

# 定义索引的标签
labels = ['总分', '成分A', '成分B', '成分C', '成分D', '成分E', '成分F', '成分G']
relative_change_df.index = labels  # 将标签赋值给索引

# %%
# 作图
plt.figure(figsize=(12, 8))

def percent_formatter(x, pos):
    return f'{x:.0f}%'

# Create the heatmap
heatmap = sns.heatmap(relative_change_df.T , cmap='RdBu_r', annot=True, fmt='.0f',
                      annot_kws={'size': 10, 'fontproperties': font_prop},
                      vmin=-10, vmax=10)


# Set title and labels with font properties
plt.title('使用前后psqi总分及各成分得分变化(使用后-使用前)', fontproperties=font_prop, fontsize=16)
plt.xlabel('', fontproperties=font_prop, fontsize=14)
plt.ylabel('')  # Remove Y-axis label

# Set the font properties for tick labels and rotate Y-axis labels
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontproperties=font_prop, fontsize=12)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontproperties=font_prop, fontsize=12, rotation=0)  # Rotate labels

plt.savefig("../result/使用前后psqi总分及各成分得分变化热力图.png")
plt.show()
# Out:
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24635 (\N{CJK UNIFIED IDEOGRAPH-603B}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27784 (\N{CJK UNIFIED IDEOGRAPH-6C88}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22763 (\N{CJK UNIFIED IDEOGRAPH-58EB}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 22269 (\N{CJK UNIFIED IDEOGRAPH-56FD}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21457 (\N{CJK UNIFIED IDEOGRAPH-53D1}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29748 (\N{CJK UNIFIED IDEOGRAPH-7434}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24464 (\N{CJK UNIFIED IDEOGRAPH-5F90}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24742 (\N{CJK UNIFIED IDEOGRAPH-60A6}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 37073 (\N{CJK UNIFIED IDEOGRAPH-90D1}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24935 (\N{CJK UNIFIED IDEOGRAPH-6167}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20446 (\N{CJK UNIFIED IDEOGRAPH-4FDE}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24535 (\N{CJK UNIFIED IDEOGRAPH-5FD7}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27743 (\N{CJK UNIFIED IDEOGRAPH-6C5F}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38889 (\N{CJK UNIFIED IDEOGRAPH-97E9}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24605 (\N{CJK UNIFIED IDEOGRAPH-601D}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27905 (\N{CJK UNIFIED IDEOGRAPH-6D01}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26472 (\N{CJK UNIFIED IDEOGRAPH-6768}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38597 (\N{CJK UNIFIED IDEOGRAPH-96C5}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20848 (\N{CJK UNIFIED IDEOGRAPH-5170}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29579 (\N{CJK UNIFIED IDEOGRAPH-738B}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29788 (\N{CJK UNIFIED IDEOGRAPH-745C}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27748 (\N{CJK UNIFIED IDEOGRAPH-6C64}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33600 (\N{CJK UNIFIED IDEOGRAPH-8340}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 34261 (\N{CJK UNIFIED IDEOGRAPH-85D5}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23075 (\N{CJK UNIFIED IDEOGRAPH-5A23}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21016 (\N{CJK UNIFIED IDEOGRAPH-5218}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 27754 (\N{CJK UNIFIED IDEOGRAPH-6C6A}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26122 (\N{CJK UNIFIED IDEOGRAPH-660A}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 29976 (\N{CJK UNIFIED IDEOGRAPH-7518}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 39062 (\N{CJK UNIFIED IDEOGRAPH-9896}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 23159 (\N{CJK UNIFIED IDEOGRAPH-5A77}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 36153 (\N{CJK UNIFIED IDEOGRAPH-8D39}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 33395 (\N{CJK UNIFIED IDEOGRAPH-8273}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 20174 (\N{CJK UNIFIED IDEOGRAPH-4ECE}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 24314 (\N{CJK UNIFIED IDEOGRAPH-5EFA}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 26126 (\N{CJK UNIFIED IDEOGRAPH-660E}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 38472 (\N{CJK UNIFIED IDEOGRAPH-9648}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 19996 (\N{CJK UNIFIED IDEOGRAPH-4E1C}) missing from current font.
#   fig.canvas.draw()
# /home/lwd/anaconda3/envs/pytorch/lib/python3.9/site-packages/seaborn/utils.py:61: UserWarning: Glyph 21319 (\N{CJK UNIFIED IDEOGRAPH-5347}) missing from current font.
#   fig.canvas.draw()
